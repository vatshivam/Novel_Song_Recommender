# %%
import numpy as np
import pandas as pd

# %%
artist_details = pd.read_csv('../data/artist_details.csv',index_col=0)

# %%
artist_details.drop()
# Out:
#        Column1 artist_names                track_id  popularity  \
# 0            0    Bob Dylan  3AhXZa8sUQht0UEdBJgpGc        71.0
# 1            0    Bob Dylan  3AhXZa8sUQht0UEdBJgpGc        71.0
# 2            0    Bob Dylan  3AhXZa8sUQht0UEdBJgpGc        71.0
# 3            0    Bob Dylan  3AhXZa8sUQht0UEdBJgpGc        71.0
# 4            0    Bob Dylan  3AhXZa8sUQht0UEdBJgpGc        71.0
# ...        ...          ...                     ...         ...
# 54455     9731       Redman  3h66NhIvR5cgi2xJlUUmgd        65.0
# 54456     9731       Redman  3h66NhIvR5cgi2xJlUUmgd        65.0
# 54457     9731       Redman  3h66NhIvR5cgi2xJlUUmgd        65.0
# 54458     9731       Redman  3h66NhIvR5cgi2xJlUUmgd        65.0
# 54459     9731       Redman  3h66NhIvR5cgi2xJlUUmgd        65.0
#
#                    Value
# 0             album rock
# 1           classic rock
# 2           country rock
# 3                   folk
# 4              folk rock
# ...                  ...
# 54455            hip hop
# 54456     new jersey rap
# 54457                rap
# 54458   southern hip hop
# 54459             wu fam
#
# [54460 rows x 5 columns]

# %%
artist_details.drop(columns=['Popularity2'],inplace=True)

# %%
artist_details = artist_details.round(2)

# %%
artist_details['popularity'].value_counts()
# Out:
# 59.0     2055
# 62.0     1983
# 61.0     1773
# 57.0     1724
# 58.0     1689
#          ...
# 26.5        4
# 100.0       4
# 24.5        3
# 13.5        3
# 92.0        2
# Name: popularity, Length: 208, dtype: int64

# %%
cols_to_check =['artist_names','track_id','genre']
artist_details[cols_to_check] = artist_details[cols_to_check].replace({"]":""}, regex=True)
artist_details[cols_to_check] = artist_details[cols_to_check].replace({"'":""}, regex=True)
artist_details['artist_names'] = artist_details['artist_names'].str.replace('[','',regex=True)
artist_details['genre'] = artist_details['genre'].str.replace('[','', regex=True)
artist_details.head()
# Out:
#      artist_names                track_id  \
# 0       Bob Dylan  3AhXZa8sUQht0UEdBJgpGc
# 1         Nirvana  5ghIJDpPoe3CfHMGu71E6T
# 2     The Beatles  0hKRSZhUGEhKU6aNSPBACZ
# 3  The Beach Boys  5Qt4Cc66g24QWwGP3YYV9y
# 4     Chuck Berry  2QfiRTz5Yc8DdShCxG1tB2
#
#                                                genre popularity
# 0  album rock, classic rock, country rock, folk, ...       [71]
# 1     alternative rock, grunge, permanent wave, rock       [81]
# 2  beatlesque, british invasion, classic rock, me...       [83]
# 3  baroque pop, brill building pop, classic rock,...       [72]
# 4      classic rock, rock, rock-and-roll, rockabilly       [65]

# %%
temp = artist_details.popularity.str.replace('[','')
temp = temp.str.replace(']','')

# %%
artist_details.popularity = artist_details.popularity.apply(eval)

# %%
artist_details.popularity = artist_details.popularity.apply(lambda X : 0 if not len(X) else sum(X)/len(X))

# %%
artist_details.to_csv('../data/artist_details.csv')

# %%
artist_details
# Out:
#        Column1 artist_names                track_id  popularity  \
# 0            0    Bob Dylan  3AhXZa8sUQht0UEdBJgpGc        71.0
# 1            0    Bob Dylan  3AhXZa8sUQht0UEdBJgpGc        71.0
# 2            0    Bob Dylan  3AhXZa8sUQht0UEdBJgpGc        71.0
# 3            0    Bob Dylan  3AhXZa8sUQht0UEdBJgpGc        71.0
# 4            0    Bob Dylan  3AhXZa8sUQht0UEdBJgpGc        71.0
# ...        ...          ...                     ...         ...
# 54455     9731       Redman  3h66NhIvR5cgi2xJlUUmgd        65.0
# 54456     9731       Redman  3h66NhIvR5cgi2xJlUUmgd        65.0
# 54457     9731       Redman  3h66NhIvR5cgi2xJlUUmgd        65.0
# 54458     9731       Redman  3h66NhIvR5cgi2xJlUUmgd        65.0
# 54459     9731       Redman  3h66NhIvR5cgi2xJlUUmgd        65.0
#
#                    Value
# 0             album rock
# 1           classic rock
# 2           country rock
# 3                   folk
# 4              folk rock
# ...                  ...
# 54455            hip hop
# 54456     new jersey rap
# 54457                rap
# 54458   southern hip hop
# 54459             wu fam
#
# [54460 rows x 5 columns]

# %%
tracks = pd.read_csv('../data/truncated_tracks.csv',index_col=0)

# %%
artist_details = pd.read_csv('../data/artist_details.csv',index_col=0)

# %%
artist_details['artist_names'] == '1(remastered)'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54455    False
# 54456    False
# 54457    False
# 54458    False
# 54459    False
# Name: artist_names, Length: 54460, dtype: bool

# %%
tracks.album_name.sort_values()[:50]
# Out:
# 4188            !Volare! The Very Best of the Gipsy Kings
# 507                           "A Few Good Men" Soundtrack
# 926                                    "Awaken, My Love!"
# 29                               "Heroes" (2017 Remaster)
# 2219                                        "Os Mutantes"
# 4069                                        "Os Mutantes"
# 7644               "What Is This Heart?" (Deluxe Edition)
# 2996                            "the original" Set It Off
# 1740                                                   #1
# 6716                                  #1 Hits Of The 60's
# 2943                                            #1 Record
# 9075                                            #1 Record
# 608                                             #1 Record
# 7680           #3 (Ce n'est pas perdu pour tout le monde)
# 7184                                                  $O$
# 3459                                   '60s Ska Explosion
# 7883                                        '74 Jailbreak
# 1351                                        '80s Pop #1's
# 3121                           '80s Urban Beats & Grooves
# 2431                                'Round About Midnight
# 6851                                                  ( )
# 9806                                                  ( )
# 1317                                       (I'm) Stranded
# 1640                                                 (II)
# 7139                                                 (II)
# 3586    (If Loving You Is Wrong) I Don't Want to Be Right
# 3081    (Rotten Apples) The Smashing Pumpkins Greatest...
# 3678                          (Turn On) The Music Machine
# 5421                               (Untitled) /(Unissued)
# 711     (What's The Story) Morning Glory? (Deluxe Rema...
# 4759    (What's The Story) Morning Glory? (Deluxe Rema...
# 2494    (What's The Story) Morning Glory? (Deluxe Rema...
# 3856    (What's The Story) Morning Glory? (Deluxe Rema...
# 6684    (What's The Story) Morning Glory? (Deluxe Rema...
# 99      (What's The Story) Morning Glory? (Deluxe Rema...
# 826     (What's The Story) Morning Glory? (Deluxe Rema...
# 2784     (Who's Afraid Of) The Art Of Noise? [Remastered]
# 7164     (Who's Afraid Of) The Art Of Noise? [Remastered]
# 7807                ... Y Su Guantanamera (Remasterizado)
# 1318    ...And Justice for All (Remastered Deluxe Box ...
# 7884                  ...And Justice for All (Remastered)
# 5453                           ...And Out Come The Wolves
# 4413                           ...And Out Come The Wolves
# 5553                              ...And Then There Was X
# 567        ...Baby One More Time (Digital Deluxe Version)
# 8294                    ...But Seriously (Deluxe Edition)
# 9141                                    ...Like Clockwork
# 4453                                    ...Like Clockwork
# 5433                              ...Nothing Like The Sun
# 6343                              ...Nothing Like The Sun
# Name: album_name, dtype: object
